# %%
import cv2

# %%
# Read Image

img = cv2.imread('dog.png')

newimg = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
import matplotlib.pyplot as plt

plt.imshow(img)
plt.show()

plt.imshow(newimg)
plt.show()
